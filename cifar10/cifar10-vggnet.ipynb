# %% [markdown]
# # 加载数据集

# %%
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
import os
from PIL import Image
import numpy as np
import glob

# %%
label_name = ["airplane", "automobile", "bird",
              "cat", "deer", "dog",
              "frog", "horse", "ship", "truck"]

label_dict = {}

for idx, name in enumerate(label_name):
    label_dict[name] = idx

# %%
def default_loader(path):
    return Image.open(path).convert("RGB")


train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465),
                         (0.2023, 0.1994, 0.2010)),
])

test_transform = transforms.Compose([
    transforms.CenterCrop((32, 32)),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465),
                         (0.2023, 0.1994, 0.2010)),
])

# %%
class MyDataset(Dataset):
    def __init__(self, im_list,
                 transform=None,
                 loader = default_loader):
        super(MyDataset, self).__init__()
        imgs = []

        for im_item in im_list:
            #"/home/kuan/dataset/CIFAR10/TRAIN/" \
            #"airplane/aeroplane_s_000021.png"
            im_label_name = im_item.split("/")[-2]
            imgs.append([im_item, label_dict[im_label_name]])

        self.imgs = imgs
        self.transform = transform
        self.loader = loader

    def __getitem__(self, index):
        im_path, im_label = self.imgs[index]
        im_data = self.loader(im_path)
        if self.transform is not None:
            im_data = self.transform(im_data)

        return im_data, im_label

    def __len__(self):
        return len(self.imgs)

# %%
im_train_list = glob.glob("TRAIN/*/*.png")
im_test_list = glob.glob("TEST/*/*.png")


train_dataset = MyDataset(im_train_list,
                         transform=train_transform)
test_dataset = MyDataset(im_test_list,
                        transform =test_transform)

train_loader = DataLoader(dataset=train_dataset,
                               batch_size=128,
                               shuffle=True)

test_loader = DataLoader(dataset=test_dataset,
                               batch_size=128,
                               shuffle=False)

print("num_of_train", len(train_dataset))
print("num_of_test", len(test_dataset))
# Out:
# num_of_train 50000
# num_of_test 10000

# %% [markdown]
# # VGGnet

# %%
# coding=utf-8
import torch
import torch.nn as nn
import torchvision
import os

# %%
import torch.nn.functional as F

# %%
def train(model, train_loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    epoch_loss = running_loss / total
    epoch_acc = correct / total
    return epoch_loss, epoch_acc

# %%
def test(model, test_loader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            running_loss += loss.item() * inputs.size(0)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    epoch_loss = running_loss / total
    epoch_acc = correct / total
    return epoch_loss, epoch_acc

# %%
class VGGbase(nn.Module):
    def __init__(self):
        super(VGGbase, self).__init__()

        # 3 * 28 * 28 (crop-->32, 28)
        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU()
        )
        self.max_pooling1 = nn.MaxPool2d(kernel_size=2, stride=2)

        # 14 * 14
        self.conv2_1 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU()
        )

        self.conv2_2 = nn.Sequential(
            nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU()
        )

        self.max_pooling2 = nn.MaxPool2d(kernel_size=2, stride=2)

        # 7 * 7
        self.conv3_1 = nn.Sequential(
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU()
        )

        self.conv3_2 = nn.Sequential(
            nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU()
        )

        self.max_pooling3 = nn.MaxPool2d(kernel_size=2,
                                         stride=2,
                                         padding=1)

        # 4 * 4
        self.conv4_1 = nn.Sequential(
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU()
        )

        self.conv4_2 = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU()
        )
        self.max_pooling4 = nn.MaxPool2d(kernel_size=2,
                                         stride=2)

        # batchsize * 512 * 2 *2 --> batchsize * (512 * 4)
        self.fc = nn.Linear(512 * 4, 10)

    def forward(self, x):
        batchsize = x.size(0)
        out = self.conv1(x)
        out = self.max_pooling1(out)
        out = self.conv2_1(out)
        out = self.conv2_2(out)
        out = self.max_pooling2(out)

        #
        out = self.conv3_1(out)
        out = self.conv3_2(out)
        out = self.max_pooling3(out)

        out = self.conv4_1(out)
        out = self.conv4_2(out)
        out = self.max_pooling4(out)
        #
        out = out.view(batchsize, -1)
        # batchsize * c * h * w --> batchsize * n

        out = self.fc(out) # batchsize * 11
        out = F.log_softmax(out, dim=1)

        return out

# %%
#是否使用GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
epoch_num = 200
lr = 0.1
batch_size = 128
model = VGGbase()

# %%
#loss
loss_func = nn.CrossEntropyLoss()
#optimizer
optimizer = torch.optim.Adam(model.parameters(), lr= lr)
model.to(device)
# Out:
# VGGbase(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (max_pooling1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2_1): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (conv2_2): Sequential(
#     (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (max_pooling2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3_1): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (conv3_2): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (max_pooling3): MaxPool2d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (conv4_1): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (conv4_2): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (max_pooling4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc): Linear(in_features=2048, out_features=10, bias=True)
# )

# %%
for epoch in range(epoch_num):
    train_loss, train_acc = train(model, train_loader, loss_func, optimizer, device)
    test_loss, test_acc = test(model,test_loader, loss_func, device)
    print(
        f"Epoch {epoch + 1}/{epoch_num}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}")
# Out:
# Epoch 1/200, Train Loss: 3.2801, Train Acc: 0.1019, Test Loss: 2.3007, Test Acc: 0.1108
# Epoch 2/200, Train Loss: 2.2838, Train Acc: 0.1192, Test Loss: 2.2734, Test Acc: 0.1255
# Epoch 3/200, Train Loss: 1.9155, Train Acc: 0.2427, Test Loss: 1.8069, Test Acc: 0.3033
# Epoch 4/200, Train Loss: 1.6551, Train Acc: 0.3573, Test Loss: 1.6201, Test Acc: 0.3872
# Epoch 5/200, Train Loss: 1.4649, Train Acc: 0.4462, Test Loss: 1.4097, Test Acc: 0.4642
# Epoch 6/200, Train Loss: 1.3169, Train Acc: 0.5069, Test Loss: 1.7195, Test Acc: 0.3942
# Epoch 7/200, Train Loss: 1.2080, Train Acc: 0.5553, Test Loss: 1.2452, Test Acc: 0.5552
# Epoch 8/200, Train Loss: 1.1142, Train Acc: 0.5961, Test Loss: 1.2002, Test Acc: 0.5757
# Epoch 9/200, Train Loss: 1.0247, Train Acc: 0.6322, Test Loss: 1.1089, Test Acc: 0.6083
# Epoch 10/200, Train Loss: 0.9536, Train Acc: 0.6600, Test Loss: 1.0850, Test Acc: 0.6232
# Epoch 11/200, Train Loss: 0.8966, Train Acc: 0.6818, Test Loss: 1.0656, Test Acc: 0.6336
# Epoch 12/200, Train Loss: 0.8462, Train Acc: 0.6965, Test Loss: 0.9454, Test Acc: 0.6677
# Epoch 13/200, Train Loss: 0.8006, Train Acc: 0.7159, Test Loss: 0.9857, Test Acc: 0.6535
# Epoch 14/200, Train Loss: 0.7702, Train Acc: 0.7287, Test Loss: 0.8292, Test Acc: 0.7090
# Epoch 15/200, Train Loss: 0.7316, Train Acc: 0.7450, Test Loss: 0.8513, Test Acc: 0.7034
# Epoch 16/200, Train Loss: 0.7055, Train Acc: 0.7507, Test Loss: 0.8754, Test Acc: 0.6943
# Epoch 17/200, Train Loss: 0.6749, Train Acc: 0.7644, Test Loss: 0.8783, Test Acc: 0.7056
# Epoch 18/200, Train Loss: 0.6488, Train Acc: 0.7736, Test Loss: 0.8286, Test Acc: 0.7340
# Epoch 19/200, Train Loss: 0.6312, Train Acc: 0.7817, Test Loss: 0.7989, Test Acc: 0.7327
# Epoch 20/200, Train Loss: 0.6041, Train Acc: 0.7902, Test Loss: 0.8216, Test Acc: 0.7355
# Epoch 21/200, Train Loss: 0.5824, Train Acc: 0.7992, Test Loss: 0.7493, Test Acc: 0.7496
# Epoch 22/200, Train Loss: 0.5572, Train Acc: 0.8084, Test Loss: 0.6822, Test Acc: 0.7702
# Epoch 23/200, Train Loss: 0.5329, Train Acc: 0.8160, Test Loss: 0.7398, Test Acc: 0.7526
# Epoch 24/200, Train Loss: 0.5172, Train Acc: 0.8201, Test Loss: 0.7588, Test Acc: 0.7492
# Epoch 25/200, Train Loss: 0.5015, Train Acc: 0.8264, Test Loss: 0.7526, Test Acc: 0.7672
# Epoch 26/200, Train Loss: 0.4824, Train Acc: 0.8347, Test Loss: 0.7431, Test Acc: 0.7642
# Epoch 27/200, Train Loss: 0.4706, Train Acc: 0.8371, Test Loss: 0.7388, Test Acc: 0.7668
# Epoch 28/200, Train Loss: 0.4608, Train Acc: 0.8408, Test Loss: 0.7850, Test Acc: 0.7577
# Epoch 29/200, Train Loss: 0.4469, Train Acc: 0.8482, Test Loss: 0.7068, Test Acc: 0.7760
# Epoch 30/200, Train Loss: 0.4306, Train Acc: 0.8515, Test Loss: 0.7342, Test Acc: 0.7706
# Epoch 31/200, Train Loss: 0.4045, Train Acc: 0.8600, Test Loss: 0.7088, Test Acc: 0.7740
# Epoch 32/200, Train Loss: 0.4087, Train Acc: 0.8602, Test Loss: 0.7243, Test Acc: 0.7862
# Epoch 33/200, Train Loss: 0.3872, Train Acc: 0.8669, Test Loss: 0.7563, Test Acc: 0.7809
# Epoch 34/200, Train Loss: 0.3748, Train Acc: 0.8712, Test Loss: 0.7341, Test Acc: 0.7840
# Epoch 35/200, Train Loss: 0.3611, Train Acc: 0.8773, Test Loss: 0.7343, Test Acc: 0.7860
# Epoch 36/200, Train Loss: 0.3574, Train Acc: 0.8762, Test Loss: 0.6735, Test Acc: 0.8050
# Epoch 37/200, Train Loss: 0.3411, Train Acc: 0.8820, Test Loss: 0.7475, Test Acc: 0.7723
# Epoch 38/200, Train Loss: 0.3301, Train Acc: 0.8865, Test Loss: 0.7171, Test Acc: 0.7851
# Epoch 39/200, Train Loss: 0.3133, Train Acc: 0.8920, Test Loss: 0.7241, Test Acc: 0.7933
# Epoch 40/200, Train Loss: 0.3148, Train Acc: 0.8913, Test Loss: 0.7771, Test Acc: 0.7866
# Epoch 41/200, Train Loss: 0.3099, Train Acc: 0.8935, Test Loss: 0.7277, Test Acc: 0.7855
# Epoch 42/200, Train Loss: 0.2937, Train Acc: 0.8975, Test Loss: 0.6681, Test Acc: 0.8009
# Epoch 43/200, Train Loss: 0.2789, Train Acc: 0.9040, Test Loss: 0.7317, Test Acc: 0.7954
# Epoch 44/200, Train Loss: 0.2747, Train Acc: 0.9056, Test Loss: 0.7433, Test Acc: 0.7891
# Epoch 45/200, Train Loss: 0.2717, Train Acc: 0.9070, Test Loss: 0.7035, Test Acc: 0.7919
# Epoch 46/200, Train Loss: 0.2646, Train Acc: 0.9094, Test Loss: 0.7341, Test Acc: 0.7962
# Epoch 47/200, Train Loss: 0.2486, Train Acc: 0.9136, Test Loss: 0.9198, Test Acc: 0.7729
# Epoch 48/200, Train Loss: 0.2461, Train Acc: 0.9136, Test Loss: 0.7746, Test Acc: 0.7935
# Epoch 49/200, Train Loss: 0.2349, Train Acc: 0.9181, Test Loss: 0.7862, Test Acc: 0.7972
# Epoch 50/200, Train Loss: 0.2308, Train Acc: 0.9200, Test Loss: 0.7005, Test Acc: 0.8066
# Epoch 51/200, Train Loss: 0.2276, Train Acc: 0.9215, Test Loss: 0.7607, Test Acc: 0.8011
# Epoch 52/200, Train Loss: 0.2172, Train Acc: 0.9262, Test Loss: 0.7227, Test Acc: 0.7985
# Epoch 53/200, Train Loss: 0.2152, Train Acc: 0.9259, Test Loss: 0.8742, Test Acc: 0.7906
# Epoch 54/200, Train Loss: 0.2145, Train Acc: 0.9252, Test Loss: 0.7540, Test Acc: 0.8022
# Epoch 55/200, Train Loss: 0.2159, Train Acc: 0.9237, Test Loss: 0.7641, Test Acc: 0.8084
# Epoch 56/200, Train Loss: 0.1981, Train Acc: 0.9326, Test Loss: 0.7802, Test Acc: 0.7986
# Epoch 57/200, Train Loss: 0.2086, Train Acc: 0.9281, Test Loss: 0.7584, Test Acc: 0.8133
# Epoch 58/200, Train Loss: 0.1909, Train Acc: 0.9343, Test Loss: 0.8339, Test Acc: 0.7975
# Epoch 59/200, Train Loss: 0.1887, Train Acc: 0.9355, Test Loss: 0.8335, Test Acc: 0.8098
# Epoch 60/200, Train Loss: 0.1820, Train Acc: 0.9372, Test Loss: 0.8380, Test Acc: 0.8005
# Epoch 61/200, Train Loss: 0.1875, Train Acc: 0.9360, Test Loss: 0.7210, Test Acc: 0.8053
# Epoch 62/200, Train Loss: 0.1716, Train Acc: 0.9405, Test Loss: 0.9064, Test Acc: 0.7996
# Epoch 63/200, Train Loss: 0.1777, Train Acc: 0.9385, Test Loss: 0.8141, Test Acc: 0.8036
# Epoch 64/200, Train Loss: 0.1719, Train Acc: 0.9409, Test Loss: 0.7816, Test Acc: 0.8093
# Epoch 65/200, Train Loss: 0.1663, Train Acc: 0.9430, Test Loss: 0.7725, Test Acc: 0.8116
# Epoch 66/200, Train Loss: 0.1552, Train Acc: 0.9474, Test Loss: 0.8826, Test Acc: 0.8076
# Epoch 67/200, Train Loss: 0.1620, Train Acc: 0.9439, Test Loss: 0.8370, Test Acc: 0.8081
# Epoch 68/200, Train Loss: 0.1559, Train Acc: 0.9461, Test Loss: 0.7788, Test Acc: 0.8112
# Epoch 69/200, Train Loss: 0.1521, Train Acc: 0.9481, Test Loss: 0.8984, Test Acc: 0.8071
# Epoch 70/200, Train Loss: 0.1460, Train Acc: 0.9477, Test Loss: 0.8102, Test Acc: 0.8114
# Epoch 71/200, Train Loss: 0.1448, Train Acc: 0.9495, Test Loss: 0.8923, Test Acc: 0.8062
# Epoch 72/200, Train Loss: 0.1417, Train Acc: 0.9513, Test Loss: 0.8787, Test Acc: 0.8036
# Epoch 73/200, Train Loss: 0.1351, Train Acc: 0.9537, Test Loss: 0.8058, Test Acc: 0.8040
# Epoch 74/200, Train Loss: 0.1367, Train Acc: 0.9528, Test Loss: 0.9385, Test Acc: 0.8084
# Epoch 75/200, Train Loss: 0.1400, Train Acc: 0.9514, Test Loss: 0.8014, Test Acc: 0.8105
# Epoch 76/200, Train Loss: 0.1382, Train Acc: 0.9518, Test Loss: 0.9962, Test Acc: 0.8022
# Epoch 77/200, Train Loss: 0.1271, Train Acc: 0.9561, Test Loss: 0.8039, Test Acc: 0.8183
# Epoch 78/200, Train Loss: 0.1283, Train Acc: 0.9557, Test Loss: 0.8650, Test Acc: 0.8091
# Epoch 79/200, Train Loss: 0.1185, Train Acc: 0.9587, Test Loss: 1.0009, Test Acc: 0.8016
# Epoch 80/200, Train Loss: 0.1285, Train Acc: 0.9561, Test Loss: 0.8770, Test Acc: 0.8113
# Epoch 81/200, Train Loss: 0.1239, Train Acc: 0.9565, Test Loss: 0.9197, Test Acc: 0.8096
# Epoch 82/200, Train Loss: 0.1221, Train Acc: 0.9574, Test Loss: 0.8921, Test Acc: 0.8112
# Epoch 83/200, Train Loss: 0.1148, Train Acc: 0.9600, Test Loss: 0.9570, Test Acc: 0.8056
# Epoch 84/200, Train Loss: 0.1215, Train Acc: 0.9582, Test Loss: 0.8929, Test Acc: 0.8084
# Epoch 85/200, Train Loss: 0.1060, Train Acc: 0.9633, Test Loss: 0.9332, Test Acc: 0.8138
# Epoch 86/200, Train Loss: 0.1163, Train Acc: 0.9596, Test Loss: 0.9410, Test Acc: 0.8123
# Epoch 87/200, Train Loss: 0.1052, Train Acc: 0.9639, Test Loss: 0.9038, Test Acc: 0.8079
# Epoch 88/200, Train Loss: 0.1085, Train Acc: 0.9629, Test Loss: 0.9713, Test Acc: 0.8029
# Epoch 89/200, Train Loss: 0.1048, Train Acc: 0.9645, Test Loss: 1.0803, Test Acc: 0.8075
# Epoch 90/200, Train Loss: 0.1059, Train Acc: 0.9635, Test Loss: 0.9676, Test Acc: 0.8069
# Epoch 91/200, Train Loss: 0.1027, Train Acc: 0.9648, Test Loss: 0.9602, Test Acc: 0.8095
# Epoch 92/200, Train Loss: 0.1036, Train Acc: 0.9646, Test Loss: 0.9735, Test Acc: 0.8108
# Epoch 93/200, Train Loss: 0.1080, Train Acc: 0.9623, Test Loss: 0.9521, Test Acc: 0.8151
# Epoch 94/200, Train Loss: 0.0952, Train Acc: 0.9663, Test Loss: 0.9676, Test Acc: 0.8154
# Epoch 95/200, Train Loss: 0.0972, Train Acc: 0.9664, Test Loss: 1.0732, Test Acc: 0.7941
# Epoch 96/200, Train Loss: 0.0966, Train Acc: 0.9670, Test Loss: 1.0587, Test Acc: 0.8040
# Epoch 97/200, Train Loss: 0.1032, Train Acc: 0.9645, Test Loss: 1.0512, Test Acc: 0.8049
# Epoch 98/200, Train Loss: 0.0919, Train Acc: 0.9680, Test Loss: 0.9991, Test Acc: 0.8103
# Epoch 99/200, Train Loss: 0.1042, Train Acc: 0.9644, Test Loss: 0.9308, Test Acc: 0.8078
# Epoch 100/200, Train Loss: 0.0890, Train Acc: 0.9701, Test Loss: 0.9594, Test Acc: 0.8124
# Epoch 101/200, Train Loss: 0.0900, Train Acc: 0.9688, Test Loss: 1.0420, Test Acc: 0.8046
# Epoch 102/200, Train Loss: 0.0928, Train Acc: 0.9680, Test Loss: 1.0355, Test Acc: 0.8019
# Epoch 103/200, Train Loss: 0.0915, Train Acc: 0.9686, Test Loss: 1.0381, Test Acc: 0.8085
# Epoch 104/200, Train Loss: 0.0854, Train Acc: 0.9704, Test Loss: 0.9936, Test Acc: 0.8128
# Epoch 105/200, Train Loss: 0.0816, Train Acc: 0.9718, Test Loss: 1.0674, Test Acc: 0.8123
# Epoch 106/200, Train Loss: 0.0861, Train Acc: 0.9704, Test Loss: 1.0651, Test Acc: 0.8084
# Epoch 107/200, Train Loss: 0.0939, Train Acc: 0.9676, Test Loss: 1.0235, Test Acc: 0.8102
# Epoch 108/200, Train Loss: 0.0852, Train Acc: 0.9702, Test Loss: 1.2162, Test Acc: 0.7974
# Epoch 109/200, Train Loss: 0.0782, Train Acc: 0.9736, Test Loss: 1.1264, Test Acc: 0.8086
# Epoch 110/200, Train Loss: 0.0803, Train Acc: 0.9725, Test Loss: 1.0954, Test Acc: 0.8147
# Epoch 111/200, Train Loss: 0.0806, Train Acc: 0.9721, Test Loss: 1.0371, Test Acc: 0.8034
# Epoch 112/200, Train Loss: 0.0847, Train Acc: 0.9706, Test Loss: 1.0140, Test Acc: 0.8124
# Epoch 113/200, Train Loss: 0.0803, Train Acc: 0.9725, Test Loss: 0.9865, Test Acc: 0.8109
# Epoch 114/200, Train Loss: 0.0792, Train Acc: 0.9729, Test Loss: 1.1700, Test Acc: 0.8133
# Epoch 115/200, Train Loss: 0.0794, Train Acc: 0.9733, Test Loss: 1.0608, Test Acc: 0.8172
# Epoch 116/200, Train Loss: 0.0786, Train Acc: 0.9730, Test Loss: 1.0532, Test Acc: 0.8135
# Epoch 117/200, Train Loss: 0.0712, Train Acc: 0.9757, Test Loss: 1.1525, Test Acc: 0.8067
# Epoch 118/200, Train Loss: 0.0777, Train Acc: 0.9741, Test Loss: 1.0559, Test Acc: 0.8141
# Epoch 119/200, Train Loss: 0.0754, Train Acc: 0.9746, Test Loss: 0.9869, Test Acc: 0.8125
# Epoch 120/200, Train Loss: 0.0737, Train Acc: 0.9752, Test Loss: 1.1389, Test Acc: 0.8161
# Epoch 121/200, Train Loss: 0.0736, Train Acc: 0.9745, Test Loss: 1.1487, Test Acc: 0.8102
# Epoch 122/200, Train Loss: 0.0712, Train Acc: 0.9756, Test Loss: 1.1351, Test Acc: 0.8112
# Epoch 123/200, Train Loss: 0.0727, Train Acc: 0.9751, Test Loss: 1.2265, Test Acc: 0.8076
# Epoch 124/200, Train Loss: 0.0846, Train Acc: 0.9712, Test Loss: 1.0638, Test Acc: 0.8022
# Epoch 125/200, Train Loss: 0.0660, Train Acc: 0.9782, Test Loss: 1.1150, Test Acc: 0.8095
# Epoch 126/200, Train Loss: 0.0756, Train Acc: 0.9741, Test Loss: 1.0859, Test Acc: 0.8038
# Epoch 127/200, Train Loss: 0.0747, Train Acc: 0.9752, Test Loss: 1.1905, Test Acc: 0.8021
# Epoch 128/200, Train Loss: 0.0644, Train Acc: 0.9782, Test Loss: 1.1424, Test Acc: 0.8130
# Epoch 129/200, Train Loss: 0.0629, Train Acc: 0.9789, Test Loss: 1.1568, Test Acc: 0.8071
# Epoch 130/200, Train Loss: 0.0682, Train Acc: 0.9774, Test Loss: 1.1785, Test Acc: 0.8181
# Epoch 131/200, Train Loss: 0.0640, Train Acc: 0.9785, Test Loss: 1.2820, Test Acc: 0.8045
# Epoch 132/200, Train Loss: 0.0686, Train Acc: 0.9767, Test Loss: 1.1301, Test Acc: 0.8027
# Epoch 133/200, Train Loss: 0.0691, Train Acc: 0.9763, Test Loss: 1.1898, Test Acc: 0.8070
# Epoch 134/200, Train Loss: 0.0698, Train Acc: 0.9771, Test Loss: 1.0951, Test Acc: 0.8073
# Epoch 135/200, Train Loss: 0.0634, Train Acc: 0.9788, Test Loss: 1.0713, Test Acc: 0.7987
# Epoch 136/200, Train Loss: 0.0659, Train Acc: 0.9779, Test Loss: 1.1816, Test Acc: 0.8119
# Epoch 137/200, Train Loss: 0.0644, Train Acc: 0.9775, Test Loss: 1.1386, Test Acc: 0.8117
# Epoch 138/200, Train Loss: 0.0647, Train Acc: 0.9784, Test Loss: 1.1436, Test Acc: 0.8106
# Epoch 139/200, Train Loss: 0.0587, Train Acc: 0.9795, Test Loss: 1.2005, Test Acc: 0.8080
# Epoch 140/200, Train Loss: 0.0612, Train Acc: 0.9790, Test Loss: 1.1359, Test Acc: 0.8136
# Epoch 141/200, Train Loss: 0.0615, Train Acc: 0.9790, Test Loss: 1.1856, Test Acc: 0.8070
# Epoch 142/200, Train Loss: 0.0623, Train Acc: 0.9795, Test Loss: 1.0493, Test Acc: 0.8173
# Epoch 143/200, Train Loss: 0.0603, Train Acc: 0.9800, Test Loss: 1.1302, Test Acc: 0.8054
# Epoch 144/200, Train Loss: 0.0583, Train Acc: 0.9801, Test Loss: 1.3226, Test Acc: 0.8080
# Epoch 145/200, Train Loss: 0.0638, Train Acc: 0.9787, Test Loss: 1.1141, Test Acc: 0.8150
# Epoch 146/200, Train Loss: 0.0566, Train Acc: 0.9813, Test Loss: 1.1785, Test Acc: 0.8107
# Epoch 147/200, Train Loss: 0.0605, Train Acc: 0.9790, Test Loss: 1.1705, Test Acc: 0.8159
# Epoch 148/200, Train Loss: 0.0675, Train Acc: 0.9775, Test Loss: 1.1635, Test Acc: 0.8100
# Epoch 149/200, Train Loss: 0.0536, Train Acc: 0.9813, Test Loss: 1.1670, Test Acc: 0.8106
# Epoch 150/200, Train Loss: 0.0575, Train Acc: 0.9804, Test Loss: 1.2624, Test Acc: 0.8110
# Epoch 151/200, Train Loss: 0.0583, Train Acc: 0.9808, Test Loss: 1.1297, Test Acc: 0.8174
# Epoch 152/200, Train Loss: 0.0573, Train Acc: 0.9808, Test Loss: 1.1906, Test Acc: 0.8118
# Epoch 153/200, Train Loss: 0.0560, Train Acc: 0.9812, Test Loss: 1.2862, Test Acc: 0.7992
# Epoch 154/200, Train Loss: 0.0605, Train Acc: 0.9796, Test Loss: 1.3847, Test Acc: 0.7922
# Epoch 155/200, Train Loss: 0.0567, Train Acc: 0.9809, Test Loss: 1.2679, Test Acc: 0.8082
# Epoch 156/200, Train Loss: 0.0528, Train Acc: 0.9814, Test Loss: 1.2469, Test Acc: 0.8063
# Epoch 157/200, Train Loss: 0.0614, Train Acc: 0.9798, Test Loss: 1.1758, Test Acc: 0.8121
# Epoch 158/200, Train Loss: 0.0548, Train Acc: 0.9813, Test Loss: 1.3871, Test Acc: 0.8046
# Epoch 159/200, Train Loss: 0.0570, Train Acc: 0.9813, Test Loss: 1.2472, Test Acc: 0.8114
# Epoch 160/200, Train Loss: 0.0594, Train Acc: 0.9803, Test Loss: 1.1826, Test Acc: 0.8104
# Epoch 161/200, Train Loss: 0.0506, Train Acc: 0.9823, Test Loss: 1.3800, Test Acc: 0.8084
# Epoch 162/200, Train Loss: 0.0523, Train Acc: 0.9828, Test Loss: 1.2853, Test Acc: 0.8087
# Epoch 163/200, Train Loss: 0.0500, Train Acc: 0.9835, Test Loss: 1.2355, Test Acc: 0.8081
# Epoch 164/200, Train Loss: 0.0533, Train Acc: 0.9822, Test Loss: 1.0840, Test Acc: 0.8140
# Epoch 165/200, Train Loss: 0.0512, Train Acc: 0.9833, Test Loss: 1.3396, Test Acc: 0.8045
# Epoch 166/200, Train Loss: 0.0566, Train Acc: 0.9812, Test Loss: 1.2722, Test Acc: 0.8029
# Epoch 167/200, Train Loss: 0.0548, Train Acc: 0.9819, Test Loss: 1.0826, Test Acc: 0.8161
# Epoch 168/200, Train Loss: 0.0507, Train Acc: 0.9828, Test Loss: 1.2674, Test Acc: 0.8028
# Epoch 169/200, Train Loss: 0.0517, Train Acc: 0.9827, Test Loss: 1.2021, Test Acc: 0.8139
# Epoch 170/200, Train Loss: 0.0522, Train Acc: 0.9826, Test Loss: 1.3868, Test Acc: 0.8158
# Epoch 171/200, Train Loss: 0.0498, Train Acc: 0.9828, Test Loss: 1.2470, Test Acc: 0.8124
# Epoch 172/200, Train Loss: 0.0522, Train Acc: 0.9817, Test Loss: 1.2692, Test Acc: 0.8107
# Epoch 173/200, Train Loss: 0.0479, Train Acc: 0.9835, Test Loss: 1.2303, Test Acc: 0.8100
# Epoch 174/200, Train Loss: 0.0464, Train Acc: 0.9844, Test Loss: 1.1346, Test Acc: 0.8180
# Epoch 175/200, Train Loss: 0.0516, Train Acc: 0.9829, Test Loss: 1.4296, Test Acc: 0.8075
# Epoch 176/200, Train Loss: 0.0501, Train Acc: 0.9830, Test Loss: 1.2488, Test Acc: 0.8154
# Epoch 177/200, Train Loss: 0.0480, Train Acc: 0.9844, Test Loss: 1.2347, Test Acc: 0.8137
# Epoch 178/200, Train Loss: 0.0438, Train Acc: 0.9853, Test Loss: 1.2583, Test Acc: 0.8061
# Epoch 179/200, Train Loss: 0.0516, Train Acc: 0.9828, Test Loss: 1.2116, Test Acc: 0.8167
# Epoch 180/200, Train Loss: 0.0497, Train Acc: 0.9828, Test Loss: 1.2359, Test Acc: 0.8158
# Epoch 181/200, Train Loss: 0.0519, Train Acc: 0.9827, Test Loss: 1.2899, Test Acc: 0.8070
# Epoch 182/200, Train Loss: 0.0507, Train Acc: 0.9830, Test Loss: 1.4021, Test Acc: 0.8024
# Epoch 183/200, Train Loss: 0.0474, Train Acc: 0.9843, Test Loss: 1.2412, Test Acc: 0.8151
# Epoch 184/200, Train Loss: 0.0466, Train Acc: 0.9843, Test Loss: 1.1643, Test Acc: 0.8182
# Epoch 185/200, Train Loss: 0.0426, Train Acc: 0.9855, Test Loss: 1.2274, Test Acc: 0.8141
# Epoch 186/200, Train Loss: 0.0511, Train Acc: 0.9826, Test Loss: 1.2568, Test Acc: 0.8112
# Epoch 187/200, Train Loss: 0.0436, Train Acc: 0.9856, Test Loss: 1.1762, Test Acc: 0.8206
# Epoch 188/200, Train Loss: 0.0424, Train Acc: 0.9862, Test Loss: 1.2455, Test Acc: 0.8116
# Epoch 189/200, Train Loss: 0.0509, Train Acc: 0.9830, Test Loss: 1.2413, Test Acc: 0.8167
# Epoch 190/200, Train Loss: 0.0463, Train Acc: 0.9847, Test Loss: 1.1814, Test Acc: 0.8183
# Epoch 191/200, Train Loss: 0.0396, Train Acc: 0.9868, Test Loss: 1.3652, Test Acc: 0.8150
# Epoch 192/200, Train Loss: 0.0435, Train Acc: 0.9851, Test Loss: 1.1910, Test Acc: 0.8097
# Epoch 193/200, Train Loss: 0.0539, Train Acc: 0.9829, Test Loss: 1.1484, Test Acc: 0.8176
# Epoch 194/200, Train Loss: 0.0423, Train Acc: 0.9858, Test Loss: 1.2564, Test Acc: 0.8143
# Epoch 195/200, Train Loss: 0.0486, Train Acc: 0.9841, Test Loss: 1.4206, Test Acc: 0.8116
# Epoch 196/200, Train Loss: 0.0425, Train Acc: 0.9863, Test Loss: 1.2952, Test Acc: 0.8134
# Epoch 197/200, Train Loss: 0.0435, Train Acc: 0.9855, Test Loss: 1.3150, Test Acc: 0.8127
# Epoch 198/200, Train Loss: 0.0468, Train Acc: 0.9837, Test Loss: 1.2563, Test Acc: 0.8104
# Epoch 199/200, Train Loss: 0.0420, Train Acc: 0.9856, Test Loss: 1.3427, Test Acc: 0.8156
